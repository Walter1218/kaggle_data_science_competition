# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display 
# %matplotlib inline
train_item = "fresh_comp_offline/tianchi_fresh_comp_train_item.csv"
train_user = "fresh_comp_offline/tianchi_fresh_comp_train_user.csv"

# %%
item = pd.read_csv(train_item)
user = pd.read_csv(train_user)

# %%
display(item)
# Out:
#           item_id item_geohash  item_category
# 0       100002303          NaN           3368
# 1       100003592          NaN           7995
# 2       100006838          NaN          12630
# 3       100008089          NaN           7791
# 4       100012750          NaN           9614
# 5       100014072          NaN           1032
# 6       100014463          NaN           9023
# 7       100019387          NaN           3064
# 8       100023812          NaN           6700
# 9        10003007          NaN           5827
# 10      100030202          NaN           5932
# 11       10003122          NaN          11406
# 12      100033138          NaN          12326
# 13      100033167          NaN          11406
# 14      100039129          NaN           8561
# 15      100041366          NaN          12630
# 16      100041489          NaN          10356
# 17      100041991          NaN           5351
# 18      100042875          NaN          12090
# ...

# %%
display(user)
# Out:
#            user_id    item_id  behavior_type user_geohash  item_category  \
# 0         10001082  285259775              1      97lk14c           4076
# 1         10001082    4368907              1          NaN           5503
# 2         10001082    4368907              1          NaN           5503
# 3         10001082   53616768              1          NaN           9762
# 4         10001082  151466952              1          NaN           5232
# 5         10001082   53616768              4          NaN           9762
# 6         10001082  290088061              1          NaN           5503
# 7         10001082  298397524              1          NaN          10894
# 8         10001082   32104252              1          NaN           6513
# 9         10001082  323339743              1          NaN          10894
# 10        10001082  396795886              1          NaN           2825
# 11        10001082    9947871              1          NaN           2825
# ...

# %%
#sort operator works on user data,(user_id,item_id,time)
new_user = user.sort(['user_id','item_id','time'])
# Out:
# /Users/ent/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app

# %%
display(new_user)
# Out:
#             user_id    item_id  behavior_type user_geohash  item_category  \
# 14256733        492     254885              1          NaN           6344
# 14256863        492     254885              1          NaN           6344
# 14256925        492     254885              3          NaN           6344
# 14256735        492     254885              1          NaN           6344
# 14256761        492     254885              1          NaN           6344
# 14256821        492     254885              1          NaN           6344
# 14256852        492     254885              1          NaN           6344
# 14256853        492     254885              1          NaN           6344
# 14256944        492     254885              1          NaN           6344
# 14256950        492     254885              4          NaN           6344
# 14256972        492     254885              1          NaN           6344
# 14256708        492    2316002              1      95lkowk           6247
# ...

# %%
#sort for item here
new_item = item.sort('item_id')
# Out:
# /Users/ent/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app

# %%
display(new_item)
# Out:
#           item_id item_geohash  item_category
# 205037        958          NaN          10582
# 208749       1023          NaN            198
# 16837        1313          NaN           4245
# 271174       2213          NaN           4627
# 524636       2966          NaN          10637
# 121724       3121          NaN          10699
# 328659       3129          NaN            438
# 589049       4303          NaN           6648
# 590453       4495          NaN          10431
# 391034       6089          NaN           2443
# 395014       6619          NaN           5930
# 195219       7787          NaN           3942
# 609383       7968          NaN           5065
# 196279       8006          NaN           3537
# 613651       8731          NaN           7995
# 408464       8910          NaN           8685
# 618424       9589          NaN          11406
# 206015       9685          NaN           4582
# 207236       9940          NaN           3064
# ...

# %%
new_user.describe()
# Out:
#             user_id       item_id  behavior_type  item_category
# count  2.329103e+07  2.329103e+07   2.329103e+07   2.329103e+07
# mean   7.006868e+07  2.023214e+08   1.106268e+00   6.835397e+03
# std    4.569072e+07  1.167440e+08   4.599087e-01   3.812873e+03
# min    4.920000e+02  3.700000e+01   1.000000e+00   2.000000e+00
# 25%    3.019541e+07  1.014417e+08   1.000000e+00   3.690000e+03
# 50%    5.626942e+07  2.022430e+08   1.000000e+00   6.054000e+03
# 75%    1.166482e+08  3.035325e+08   1.000000e+00   1.027100e+04
# max    1.424430e+08  4.045625e+08   4.000000e+00   1.408000e+04

# %%
new_item.describe()
# Out:
#             item_id  item_category
# count  6.209180e+05  620918.000000
# mean   2.004351e+08    6970.213167
# std    1.191648e+08    3479.627372
# min    9.580000e+02       2.000000
# 25%    9.357641e+07    4245.000000
# 50%    2.053761e+08    6890.000000
# 75%    3.054015e+08   10120.000000
# max    4.045624e+08   14071.000000

# %%
#unique
#item id 422858 category:1054
#user id 20000 item id 4758484 id category 9557
print('in dataframe item, have unique item id number is',len(pd.Series.unique(new_item['item_id'])))
print('in dataframe item, have unique item category number is',len(pd.Series.unique(new_item['item_category'])))
print('in dataframe user, have unique user id number is',len(pd.Series.unique(new_user['user_id'])))
print('in dataframe user, have unique item id number is',len(pd.Series.unique(new_user['item_id'])))
print('in dataframe user, have unique item category number is',len(pd.Series.unique(new_user['item_category'])))
# Out:
# in dataframe item, have unique item id number is 422858
# in dataframe item, have unique item category number is 1054
# in dataframe user, have unique user id number is 20000
# in dataframe user, have unique item id number is 4758484
# in dataframe user, have unique item category number is 9557
